# %% [markdown]
# <a href="https://colab.research.google.com/github/Slaha97/Python_Course/blob/main/Day_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Day 1

# %% [markdown]
# Features of Python :
# 1) Simple and Easy
# 2) Free and Open Source
# 3) Code simplicity
# 4) Huge libraries
# 5) Huge Community

# %% [markdown]
# ## What are statically typed programming language ?

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Ex: java, c , C++ , PL/SQL

# %% [markdown]
# ## What is a dynamically typed programming language ?

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Python is an indentation programming language .

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# The print() statement is indented, so Python knows they belong to the if block.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# The block of codes should get stated in same Indentation.

# %% [markdown]
# ## Python is Case Sensitive:

# %% [markdown]
# ![image.png](data:image/png;base64,...)
